# %%
import sys
sys.path.append('../')

# %%
from ally.skills.base import TransformSkill


foodally_skill = TransformSkill(
  name="foodally_skill",
  description="""
  the social skill of foodally agents.""",
  instruction_template="""
  you are foodally, you are a very friendly friend
  """,
  input_template="""please reply in vietnamese for the question: {input}""",
  output_template=[
    {
    "name": "answer",
    "description": "the answer from foodally",
    }
  ],
  tool_names=["google-search"],
  tool_kwargs={
    "google_api_key": "AIzaSyCWsi2WcdrKvwWEke4ChNNqko8hqW795AY",
    "google_cse_id": "458a789ad42174bf7"
  },
  tool_kit_names=["foodally-toolkit"]
)

# %%
from ally.runtimes.openai import OpenAIAgentRuntime, OpenAIRuntime
from app.core.settings import settings


openai_agent_runtime = OpenAIAgentRuntime(
  verbose=True,
  api_key=settings.openai_api_key,
  gpt_model_name="gpt-4-1106-preview",
  max_tokens=2000,
)
openai_gpt_runtime = OpenAIRuntime(
  verbose=True,
  api_key=settings.openai_api_key,
  gpt_model_name="gpt-3.5-turbo",
)

# %%
from ally.agents.base import Agent

agent = Agent(
	skills=foodally_skill,
  runtimes={
    'openai': openai_agent_runtime
	},
  teacher_runtimes={
    'openai': openai_gpt_runtime
	}
)

# %%
import pandas as pd
df = pd.DataFrame([
  {"input": "chon anh xin thông tin các quán nhật nhậ có rating cao ở hà nội"},
])

# %%
from ally.utils.logs import print_dataframe


print_dataframe(agent.run(df))
# Out:
# Applying skill: foodally_skill
# 2023-12-08 20:32:49,021:INFO - file_cache is only supported with oauth2client<4.0.0
#   0%|          | 0/1 [00:00<?, ?it/s]
# {'input': 'chon anh xin thông tin các quán nhật nhậ có rating cao ở hà nội'}
# 2023-12-08 20:32:59,927:INFO - HTTP Request: GET https://vduyhyzdrhvvgqyovyhl.supabase.co/rest/v1/shop_info?select=%2A "HTTP/1.1 200 OK"
# 2023-12-08 20:33:15,111:INFO - HTTP Request: GET https://vduyhyzdrhvvgqyovyhl.supabase.co/rest/v1/shop_info?select=shop_name "HTTP/1.1 200 OK"
# 2023-12-08 20:33:15,790:INFO - HTTP Request: GET https://vduyhyzdrhvvgqyovyhl.supabase.co/rest/v1/shop_info?select=%2A&shop_name=in.%28Hashiya%20-%20%E1%BA%A8m%20Th%E1%BB%B1c%20Nh%E1%BA%ADt%20B%E1%BA%A3n%2CNgon%20Buffet%2CHadu%20Sushi%20-%20%E1%BA%A8m%20Th%E1%BB%B1c%20Nh%E1%BA%ADt%20B%E1%BA%A3n%2CBANGKOK%20-%20Thai%20Kitchen%2CNh%C3%A0%20H%C3%A0ng%20AB%2CB%C3%A0%20Nhon%20-%20B%C3%BAn%20%C4%90%E1%BA%ADu%20M%E1%BA%B9t%2CTh%E1%BB%A7y%20-%20B%C3%BAn%20Ngan%20Ch%E1%BA%B7t%2CNh%C3%A0%20H%C3%A0ng%20F%C3%AA%20-%20Buffet%20L%E1%BA%A9u%2CKokoro%20-%20%E1%BA%A8m%20Th%E1%BB%B1c%20Nh%E1%BA%ADt%20B%E1%BA%A3n%2CB%C3%A1nh%20Sinh%20Nh%E1%BA%ADt%20Th%C3%BAy%20An%29 "HTTP/1.1 200 OK"
# 2023-12-08 20:33:27,560:INFO - HTTP Request: GET https://vduyhyzdrhvvgqyovyhl.supabase.co/rest/v1/shop_info?select=%2A "HTTP/1.1 200 OK"
# agent result is
# 100%|██████████| 1/1 [01:43<00:00, 103.63s/it]
# {'input': 'chon anh xin thông tin các quán nhật nhậ có rating cao ở hà nội', 'output': 'Dưới đây là danh sách các nhà hàng Nhật Bản có rating cao ở Hà Nội mà bạn có thể quan tâm:\n\n1. Kokoro - Ẩm Thực Nhật Bản\n   Địa chỉ: 05 - 06 Khu B, Ô A10 Nguyễn Chánh, KĐT Nam Trung Yên, Quận Cầu Giấy, Hà Nội\n   Giờ mở cửa: 10:00 - 22:00\n   Rating: 9.2\n\n2. Ngon Buffet\n   Địa chỉ: 38 Ngọc Khánh, Quận Ba Đình, Hà Nội\n   Giờ mở cửa: 10:00 - 14:00 | 17:00 - 22:30\n   Rating: 9.6\n\n3. Hashiya - Ẩm Thực Nhật Bản\n   Địa chỉ: 50 Đào Tấn, Quận Ba Đình, Hà Nội\n   Giờ mở cửa: 08:00 - 22:30\n   Rating: 8.1\n\n4. Hadu Sushi - Ẩm Thực Nhật Bản\n   Địa chỉ: 276 Xã Đàn, Quận Đống Đa, Hà Nội\n   Giờ mở cửa: 10:00 - 22:00\n   Rating: 8.2\n\nLưu ý rằng thông tin trên có thể thay đổi theo thời gian, vì vậy bạn nên kiểm tra trước khi đến.', 'intermediate_steps': [(AgentAction(tool='shop_info order by rating', tool_input='I do not have the input for this action as it is not specified in the tools description. Normally, I would expect to specify a type of cuisine or a location, but since the tool description does not detail how to input such information, I will proceed without it.', log='The user is asking for information on highly rated Japanese restaurants in Hanoi. I will use the shop_info order by rating tool to find the top-rated Japanese restaurants.\n\nAction: shop_info order by rating\nAction Input: I do not have the input for this action as it is not specified in the tools description. Normally, I would expect to specify a type of cuisine or a location, but since the tool description does not detail how to input such information, I will proceed without it.'), [{'shop_id': 756, 'review_id': None, 'shop_name': '4B Tea', 'shop_kind': 'Café/Dessert', 'adress': 'X9 Thôn 6 Song Phương, X9 Thôn 6 Song Phương Hoài Đức Hoài Đức Hà Nội', 'opening_time': '08:00 - 23:00', 'opening_state': 'Đang mở cửa', 'price_ship': '10.000đ - 50.000đ', 'rating': '_._', 'total_review': '1'}, {'shop_id': 896, 'review_id': None, 'shop_name': 'Lươn O Quế - Đặc Sản Nghệ An', 'shop_kind': 'Quán ăn', 'adress': '4A Ngõ 102 Ngụy Như Kon Tum, 4A Ngõ 102 Ngụy Như Kon Tum Quận Thanh Xuân Quận Thanh Xuân Hà Nội', 'opening_time': '06:30 - 22:00', 'opening_state': 'Đang mở cửa', 'price_ship': '30.000đ - 120.000đ', 'rating': '9.9', 'total_review': '11'}, {'shop_id': 492, 'review_id': None, 'shop_name': 'Lòng Quán - Bún Đậu & Cháo Lòng', 'shop_kind': 'Quán ăn', 'adress': '107B19 Lương Định Của, 107B19 Lương Định Của Quận Đống Đa Quận Đống Đa Hà Nội', 'opening_time': '09:00 - 22:00', 'opening_state': 'Đang mở cửa', 'price_ship': '50.000đ - 200.000đ', 'rating': '9.8', 'total_review': '1'}, {'shop_id': 642, 'review_id': None, 'shop_name': 'Bánh Mì Thịt Nướng Than Hoa Nghệ An - Tố Hữu', 'shop_kind': 'Ăn vặt/vỉa hè', 'adress': 'CT4 The Pride Tố Hữu, CT4 The Pride Tố Hữu Quận Hà Đông Quận Hà Đông Hà Nội', 'opening_time': '06:30 - 18:00', 'opening_state': 'Chưa mở cửa', 'price_ship': '20.000đ - 25.000đ', 'rating': '9.8', 'total_review': '1'}, {'shop_id': 676, 'review_id': None, 'shop_name': 'Cơm Tấm Út Thắng', 'shop_kind': 'Quán ăn', 'adress': '105 B8 Tô Hiệu, P. Nghĩa Tân, 105 B8 Tô Hiệu, P. Nghĩa Tân Quận Cầu Giấy Quận Cầu Giấy Hà Nội', 'opening_time': '08:00 - 22:00', 'opening_state': 'Đang mở cửa', 'price_ship': '30.000đ - 70.000đ', 'rating': '9.8', 'total_review': '7'}, {'shop_id': 834, 'review_id': None, 'shop_name': 'Bánh Mì Hà Thành - Nguyễn Tuân', 'shop_kind': 'Ăn vặt/vỉa hè', 'adress': '31 Nguyễn Tuân, 31 Nguyễn Tuân Quận Thanh Xuân Quận Thanh Xuân Hà Nội', 'opening_time': '06:00 - 23:00', 'opening_state': 'Đang mở cửa', 'price_ship': '15.000đ - 25.000đ', 'rating': '9.8', 'total_review': '1'}, {'shop_id': 941, 'review_id': None, 'shop_name': 'Nghĩa Sơn - Gà Tươi Mạnh Hoạch', 'shop_kind': 'Quán ăn', 'adress': '283 Nguyễn Xiển, 283 Nguyễn Xiển Quận Thanh Xuân Quận Thanh Xuân Hà Nội', 'opening_time': '09:00 - 22:00', 'opening_state': 'Đang mở cửa', 'price_ship': '20.000đ - 300.000đ', ' ...
#
#   input                       intermediate_steps           output                      answer
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   chon anh xin thông tin      [(AgentAction(tool='shop_…   Dưới đây là danh sách các   Dưới đây là danh sách các
#   các quán nhật nhậ có        order by rating',            nhà hàng Nhật Bản có        nhà hàng Nhật Bản có
#   rating cao ở hà nội         tool_input='I do not have    rating cao ở Hà Nội mà      rating cao ở Hà Nội mà bạn
#                               the input for this action    bạn có thể quan tâm:        có thể quan tâm:
#                               as it is not specified in
#                               the tools description.       1. Kokoro - Ẩm Thực Nhật    1. Kokoro - Ẩm Thực Nhật
#                               Normally, I would expect     Bản                         Bản
#                               to specify a type of            Địa chỉ: 05 - 06 Khu        Địa chỉ: 05 - 06 Khu B,
#                               cuisine or a location, but   B, Ô A10 Nguyễn Chánh,      Ô A10 Nguyễn Chánh, KĐT
#                               since the tool description   KĐT Nam Trung Yên, Quận     Nam Trung Yên, Quận Cầu
#                               does not detail how to       Cầu Giấy, Hà Nội            Giấy, Hà Nội
#                               input such information, I       Giờ mở cửa: 10:00 -         Giờ mở cửa: 10:00 -
#                               will proceed without it.',   22:00                       22:00
#                               log='The user is asking         Rating: 9.2                 Rating: 9.2
#                               for information on highly
#                               rated Japanese restaurants   2. Ngon Buffet              2. Ngon Buffet
#                               in Hanoi. I will use the        Địa chỉ: 38 Ngọc            Địa chỉ: 38 Ngọc Khánh,
#                               shop_info order by rating    Khánh, Quận Ba Đình, Hà     Quận Ba Đình, Hà Nội
#                               tool to find the top-rated   Nội                            Giờ mở cửa: 10:00 -
#                               Japanese                        Giờ mở cửa: 10:00 -      14:00 | 17:00 - 22:30
#                               restaurants.\n\nAction:      14:00 | 17:00 - 22:30          Rating: 9.6
#                               shop_info order by              Rating: 9.6
#                               rating\nAction Input: I do                               3. Hashiya - Ẩm Thực Nhật
#                               not have the input for       3. Hashiya - Ẩm Thực Nhật   Bản
#                               this action as it is not     Bản                            Địa chỉ: 50 Đào Tấn,
#                               specified in the tools          Địa chỉ: 50 Đào Tấn,     Quận Ba Đình, Hà Nội
#                               description. Normally, I     Quận Ba Đình, Hà Nội           Giờ mở cửa: 08:00 -
#                               would expect to specify a       Giờ mở cửa: 08:00 -      22:30
#                               type of cuisine or a         22:30                          Rating: 8.1
#                               location, but since the         Rating: 8.1
#                               tool description does not                                4. Hadu Sushi - Ẩm Thực
#                               detail how to input such     4. Hadu Sushi - Ẩm Thực     Nhật Bản
#                               information, I will          Nhật Bản                       Địa chỉ: 276 Xã Đàn,
#                               proceed without it.'),          Địa chỉ: 276 Xã Đàn,     Quận Đống Đa, Hà Nội
#                               [{'shop_id': 756,            Quận Đống Đa, Hà Nội           Giờ mở cửa: 10:00 -
#                               'review_id': None,              Giờ mở cửa: 10:00 -      22:00
#                               'shop_name': '4B Tea',       22:00                          Rating: 8.2
#                               'shop_kind':                    Rating: 8.2
#                               'Café/Dessert', 'adress':                                Lưu ý rằng thông tin trên
#                               'X9 Thôn 6 Song Phương, X9   Lưu ý rằng thông tin trên   có thể thay đổi theo thời
#                               Thôn 6 Song Phương Hoài      có thể thay đổi theo thời   gian, vì vậy bạn nên kiểm
#                               Đức Hoài Đức Hà Nội',        gian, vì vậy bạn nên kiểm   tra trước khi đến.
#                               'opening_time': '08:00 -     tra trước khi đến.
#                               23:00', 'opening_state':
#                               'Đang mở cửa',
#                               'price_ship': '10.000đ -
#                               50.000đ', 'rating': '_._',
#                               'total_review': '1'},
#                               {'shop_id': 896,
#                               'review_id': None,
#                               'shop_name': 'Lươn O Quế -
#                               Đặc Sản Nghệ An',
#                               'shop_kind': 'Quán ăn',
#                               'adress': '4A Ngõ 102 Ngụy
#                               Như Kon Tum, 4A Ngõ 102
#                               Ngụy Như Kon Tum Quận
#                               Thanh Xuân Quận Thanh Xuân
#                               Hà Nội', 'opening_time':
#                               '06:30 - 22:00',
#                               'opening_state': 'Đang mở
#                               cửa', 'price_ship':
#                               '30.000đ - 120.000đ',
#                               'rating': '9.9',
#                               'total_review': '11'},
#                               {'shop_id': 492,
#                               'review_id': None,
#                               'shop_name': 'Lòng Quán -
#                               Bún Đậu & Cháo Lòng',
#                               'shop_kind': 'Quán ăn',
#                               'adress': '107B19 Lương
#                               Định Của, 107B19 Lương
#                               Định Của Quận Đống Đa Quận
#                               Đống Đa Hà Nội',
#                               'opening_time': '09:00 -
#                               22:00', 'opening_state':
#                               'Đang mở cửa',
#                               'price_ship': '50.000đ -
#                               200.000đ', 'rating':
#                               '9.8', 'total_review':
#                               '1'}, {'shop_id': 642,
#                               'review_id': None,
#                               'shop_name': 'Bánh Mì Thịt
#                               Nướng Than Hoa Nghệ An -
#                               Tố Hữu', 'shop_kind': 'Ăn
#                               vặt/vỉa hè', 'adress':
#                               'CT4 The Pride Tố Hữu, CT4
#                               The Pride Tố Hữu Quận Hà
#                               Đông Quận Hà Đông Hà Nội',
#                               'opening_time': '06:30 -
#                               18:00', 'opening_state':
#                               'Chưa mở cửa',
#                               'price_ship': '20.000đ -
#                               25.000đ', 'rating': '9.8',
#                               'total_review': '1'},
#                               {'shop_id': 676,
#                               'review_id': None,
#                               'shop_name': 'Cơm Tấm Út
#                               Thắng', 'shop_kind': 'Quán
#                               ăn', 'adress': '105 B8 Tô
#                               Hiệu, P. Nghĩa Tân, 105 B8
#                               Tô Hiệu, P. Nghĩa Tân Quận
#                               Cầu Giấy Quận Cầu Giấy Hà
#                               Nội', 'opening_time':
#                               '08:00 - 22:00',
#                               'opening_state': 'Đang mở
#                               cửa', 'price_ship':
#                               '30.000đ - 70.000đ',
#                               'rating': '9.8',
#                               'total_review': '7'},
#                               {'shop_id': 834,
#                               'review_id': None,
#                               'shop_name': 'Bánh Mì Hà
#                               Thành - Nguyễn Tuân',
#                               'shop_kind': 'Ăn vặt/vỉa
#                               hè', 'adress': '31 Nguyễn
#                               Tuân, 31 Nguyễn Tuân Quận
#                               Thanh Xuân Quận Thanh Xuân
#                               Hà Nội', 'opening_time':
#                               '06:00 - 23:00',
#                               'opening_state': 'Đang mở
#                               cửa', 'price_ship':
#                               '15.000đ - 25.000đ',
#                               'rating': '9.8',
#                               'total_review': '1'},
#                               {'shop_id': 941,
#                               'review_id': None,
#                               'shop_name': 'Nghĩa Sơn -
#                               Gà Tươi Mạnh Hoạch',
#                               'shop_kind': 'Quán ăn',
#                               'adress': '283 Nguyễn
#                               Xiển, 283 Nguyễn Xiển Quận
#                               Thanh Xuân Quận Thanh Xuân
#                               Hà Nội', 'opening_time':
#                               '09:00 - 22:00',
#                               'opening_state': 'Đang mở
#                               cửa', 'price_ship':
#                               '20.000đ - 300.000đ',
#                               'rating': '9.8',
#                               'total_review': '1'},
#                               {'shop_id': 994,
#                               'review_id': None,
#                               'shop_name': 'Hôla Fresh
#                               Noodles - Ăn Vặt Hàn Quốc
#                               - Shop Online',
#                               'shop_kind': 'Shop
#                               Online', 'adress': 'TT.
#                               C10 Nguyễn Quý Đức (Ngõ
#                               Cạnh KFC Nguyễn Trãi), TT.
#                               C10 Nguyễn Quý Đức (Ngõ
#                               Cạnh KFC Nguyễn Trãi) Quận
#                               Thanh Xuân Quận Thanh Xuân
#                               Hà Nội', 'opening_time':
#                               '07:00 - 13:00',
#                               'opening_state': 'Chưa mở
#                               cửa', 'price_ship':
#                               '20.000đ - 150.000đ',
#                               'rating': '9.8',
#                               'total_review': '2'},
#                               {'shop_id': 496,
#                               'review_id': None,
#                               'shop_name': 'Dreamming
#                               Way - Trà Sữa & Pizza',
#                               'shop_kind': 'Quán ăn',
#                               'adress': '103 Trần Quốc
#                               Hoàn, 103 Trần Quốc Hoàn
#                               Quận Cầu Giấy Quận Cầu
#                               Giấy Hà Nội',
#                               'opening_time': '09:00 -
#                               22:00', 'opening_state':
#                               'Đang mở cửa',
#                               'price_ship': '20.000đ -
#                               40.000đ', 'rating': '9.7',
#                               'total_review': '11'},
#                               {'shop_id': 806,
#                               'review_id': None,
#                               'shop_name': 'An Nhiên -
#                               Cơm Chay & Trà Hoa',
#                               'shop_kind':
#                               'Café/Dessert', 'adress':
#                               '97 Đặng Tiến Đông, 97
#                               Đặng Tiến Đông Quận Đống
#                               Đa Quận Đống Đa Hà Nội',
#                               'opening_time': '09:00 -
#                               21:00', 'opening_state':
#                               'Đang mở cửa',
#                               'price_ship': '15.000đ -
#                               200.000đ', 'rating':
#                               '9.7', 'total_review':
#                               '2'}, {'shop_id': 996,
#                               'review_id': None,
#                               'shop_name': 'Moonwork
#                               Coworking Space',
#                               'shop_kind':
#                               'Café/Dessert', 'adress':
#                               '34 Ngõ 28B Điện Biên Phủ,
#                               34 Ngõ 28B Điện Biên Phủ
#                               Quận Ba Đình Quận Ba Đình
#                               Hà Nội', 'opening_time':
#                               '08:00 - 20:30',
#                               'opening_state': 'Đang mở
#                               cửa', 'price_ship':
#                               '50.000đ - 500.000đ',
#                               'rating': '9.7',
#                               'total_review': '6'},
#                               {'shop_id': 43,
#                               'review_id': None,
#                               'shop_name': 'Ngon
#                               Buffet', 'shop_kind':
#                               'Buffet', 'adress': '38
#                               Ngọc Khánh, 38 Ngọc Khánh
#                               Quận Ba Đình Quận Ba Đình
#                               Hà Nội', 'opening_time':
#                               '10:00 - 14:00 | 17:00 -
#                               22:30', 'opening_state':
#                               'Đang mở cửa',
#                               'price_ship': '69.000đ -
#                               69.000đ', 'rating': '9.6',
#                               'total_review': '3'},
#                               {'shop_id': 163,
#                               'review_id': None,
#                               'shop_name': 'Hải Sản Quê
#                               - Shop Online',
#                               'shop_kind': 'Shop
#                               Online', 'adress':
#                               '118/211 Khương Trung,
#                               118/211 Khương Trung Quận
#                               Thanh Xuân Quận Thanh Xuân
#                               Hà Nội', 'opening_time':
#                               '09:00 - 21:00',
#                               'opening_state': 'Đang mở
#                               cửa', 'price_ship':
#                               '150.000đ - 195.000đ',
#                               'rating': '9.6',
#                               'total_review': '1'},
#                               {'shop_id': 266,
#                               'review_id': None,
#                               'shop_name': 'Trâu Ngon
#                               Quán - Hoàng Đạo Thúy',
#                               'shop_kind': 'Quán ăn',
#                               'adress': 'Tầng 1, Tòa Nhà
#                               N04 UDIC Complex, Hoàng
#                               Đạo Thúy, Tầng 1, Tòa Nhà
#                               N04 UDIC Complex, Hoàng
#                               Đạo Thúy Quận Cầu Giấy
#                               Quận Cầu Giấy Hà Nội',
#                               'opening_time': '09:00 -
#                               22:00', 'opening_state':
#                               'Đang mở cửa',
#                               'price_ship': '30.000đ -
#                               300.000đ', 'rating':
#                               '9.6', 'total_review':
#                               '2'}, {'shop_id': 272,
#                               'review_id': None,
#                               'shop_name': 'D7
#                               Restaurant', 'shop_kind':
#                               'Nhà hàng', 'adress': '7
#                               Dã Tượng, 7 Dã Tượng Quận
#                               Hoàn Kiếm Quận Hoàn Kiếm
#                               Hà Nội', 'opening_time':
#                               '09:00 - 22:30',
#                               'opening_state': 'Đang mở
#                               cửa', 'price_ship':
#                               '50.000đ - 300.000đ',
#                               'rating': '9.6',
#                               'total_review': '1'},
#                               {'shop_id': 845,
#                               'review_id': None,
#                               'shop_name': 'Brothers
#                               Rooftop Coffee',
#                               'shop_kind':
#                               'Café/Dessert', 'adress':
#                               'Tầng M, Tòa 148 Tower,
#                               148 Hoàng Quốc Việt, Tầng
#                               M, Tòa 148 Tower, 148
#                               Hoàng Quốc Việt Quận Cầu
#                               Giấy Quận Cầu Giấy Hà
#                               Nội', 'opening_time':
#                               '07:00 - 23:00',
#                               'opening_state': 'Đang mở
#                               cửa', 'price_ship':
#                               '25.000đ - 80.000đ',
#                               'rating': '9.6',
#                               'total_review': '7'},
#                               {'shop_id': 851,
#                               'review_id': None,
#                               'shop_name': 'Cà Phê Đông
#                               Dương', 'shop_kind':
#                               'Café/Dessert', 'adress':
#                               '8 Mai Anh Tuấn, 8 Mai Anh
#                               Tuấn Quận Đống Đa Quận
#                               Đống Đa Hà Nội',
#                               'opening_time': '07:00 -
#                               23:00', 'opening_state':
#                               'Đang mở cửa',
#                               'price_ship': '10.000đ -
#                               40.000đ', 'rating': '9.6',
#                               'total_review': '3'},
#                               {'shop_id': 852,
#                               'review_id': None,
#                               'shop_name': 'Kiều Hoa
#                               Quán - Gà Cái Bang, Vịt Hồ
#                               Lô & Dimsum', 'shop_kind':
#                               'Nhà hàng', 'adress': '291
#                               Tô Hiệu, 291 Tô Hiệu Quận
#                               Cầu Giấy Quận Cầu Giấy Hà
#                               Nội', 'opening_time':
#                               '10:00 - 22:30',
#                               'opening_state': 'Đang mở
#                               cửa', 'price_ship':
#                               '50.000đ - 250.000đ',
#                               'rating': '9.6',
#                               'total_review': '1'},
#                               {'shop_id': 187,
#                               'review_id': None,
#                               'shop_name': 'Buffet
#                               Poseidon - Seafood BBQ &
#                               Hotpot Buffet - Artemis
#                               Tower', 'shop_kind':
#                               'Buffet', 'adress': 'Tầng
#                               3, Artemis Tower, 3 Lê
#                               Trọng Tấn, Tầng 3, Artemis
#                               Tower, 3 Lê Trọng Tấn Quận
#                               Thanh Xuân Quận Thanh Xuân
#                               Hà Nội', 'opening_time':
#                               '10:00 - 22:00',
#                               'opening_state': 'Đang mở
#                               cửa', 'price_ship':
#                               '298.000đ - 338.000đ',
#                               'rating': '9.5',
#                               'total_review': '17'},
#                               {'shop_id': 326,
#                               'review_id': None,
#                               'shop_name': 'Ếch Xanh
#                               Quán - Ếch Các Món',
#                               'shop_kind': 'Quán ăn',
#                               'adress': '90 Triệu Việt
#                               Vương, 90 Triệu Việt Vương
#                               Quận Hai Bà Trưng Quận Hai
#                               Bà Trưng Hà Nội',
#                               'opening_time': '09:00 -
#                               23:00', 'opening_state':
#                               'Đang mở cửa',
#                               'price_ship': '100.000đ -
#                               300.000đ', 'rating':
#                               '9.5', 'total_review':
#                               '2'}, {'shop_id': 361,
#                               'review_id': None,
#                               'shop_name': 'Cơm Gà 360°
#                               Singapore', 'shop_kind':
#                               'Quán ăn', 'adress': '32
#                               Lê Thái Tổ, 32 Lê Thái Tổ
#                               Quận Hoàn Kiếm Quận Hoàn
#                               Kiếm Hà Nội',
#                               'opening_time': '09:00 -
#                               22:00', 'opening_state':
#                               'Đang mở cửa',
#                               'price_ship': '30.000đ -
#                               100.000đ', 'rating':
#                               '9.5', 'total_review':
#                               '2'}, {'shop_id': 237,
#                               'review_id': None,
#                               'shop_name': 'Đường Tăng -
#                               Buffet BBQ & Hotpot',
#                               'shop_kind': 'Quán ăn',
# ...
#                               Online', 'shop_kind':
#                               'Shop Online', 'adress':
#                               '1 Ngõ 219 Nguyễn Ngọc Nại
#                               (Vào Ngõ 50m Đối Diện Số
#                               10), 1 Ngõ 219 Nguyễn Ngọc
#                               Nại (Vào Ngõ 50m Đối Diện
#                               Số 10) Quận Thanh Xuân
#                               Quận Thanh Xuân Hà Nội',
#                               'opening_time': '07:00 -
#                               22:00', 'opening_state':
#                               'Đang mở cửa',
#                               'price_ship': '50.000đ -
#                               300.000đ', 'rating':
#                               '8.5', 'total_review':
#                               '13'}, {'shop_id': 465,
#                               'review_id': None,
#                               'shop_name': 'Homefood -
#                               Thực Phẩm Sạch Online',
#                               'shop_kind': 'Shop
#                               Online', 'adress': '71 Ngõ
#                               178 Ngõ Chợ Khâm Thiên, 71
#                               Ngõ 178 Ngõ Chợ Khâm Thiên
#                               Quận Đống Đa Quận Đống Đa
#                               Hà Nội', 'opening_time':
#                               '08:00 - 14:00',
#                               'opening_state': 'Chưa mở
#                               cửa', 'price_ship':
#                               '28.000đ - 70.000đ',
#                               'rating': '8.5',
#                               'total_review': '2'},
#                               {'shop_id': 538,
#                               'review_id': None,
#                               'shop_name': 'Xôi Gà Bỏ Lò
#                               - Xã Đàn - Shop Online',
#                               'shop_kind': 'Shop
#                               Online', 'adress': '198 Xã
#                               Đàn, 198 Xã Đàn Quận Đống
#                               Đa Quận Đống Đa Hà Nội',
#                               'opening_time': '08:30 -
#                               21:00', 'opening_state':
#                               'Đang mở cửa',
#                               'price_ship': '50.000đ -
#                               120.000đ', 'rating':
#                               '8.5', 'total_review':
#                               '107'}, {'shop_id': 593,
#                               'review_id': None,
#                               'shop_name': 'JW Café - JW
#                               Marriott Hotel Hanoi',
#                               'shop_kind': 'Sang trọng,
#                               Café/Dessert', 'adress':
#                               'JW Marriott Hotel Hanoi,
#                               8 Đỗ Đức Dục, JW Marriott
#                               Hotel Hanoi, 8 Đỗ Đức Dục
#                               Quận Nam Từ Liêm Quận Nam
#                               Từ Liêm Hà Nội',
#                               'opening_time': '07:00 -
#                               22:30', 'opening_state':
#                               'Đang mở cửa',
#                               'price_ship': '50.000đ -
#                               500.000đ', 'rating':
#                               '8.5', 'total_review':
#                               '20'}, {'shop_id': 698,
#                               'review_id': None,
#                               'shop_name': 'Nhà Hàng
#                               Chay V Home', 'shop_kind':
#                               'Nhà hàng', 'adress':
#                               'Tầng 2, 40 Đường Thành,
#                               Tầng 2, 40 Đường Thành
#                               Quận Hoàn Kiếm Quận Hoàn
#                               Kiếm Hà Nội',
#                               'opening_time': '08:00 -
#                               22:00', 'opening_state':
#                               'Đang mở cửa',
#                               'price_ship': '100.000đ -
#                               300.000đ', 'rating':
#                               '8.5', 'total_review':
#                               '11'}, {'shop_id': 759,
#                               'review_id': None,
#                               'shop_name': 'Di Hòa Viên
#                               - Ẩm Thực Chim Rừng',
#                               'shop_kind': 'Quán ăn',
#                               'adress': '103 Trần Quốc
#                               Vượng, 103 Trần Quốc Vượng
#                               Quận Cầu Giấy Quận Cầu
#                               Giấy Hà Nội',
#                               'opening_time': '08:00 -
#                               23:00', 'opening_state':
#                               'Đang mở cửa',
#                               'price_ship': '100.000đ -
#                               300.000đ', 'rating':
#                               '8.5', 'total_review':
#                               '5'}, {'shop_id': 769,
#                               'review_id': None,
#                               'shop_name': 'Nhà Gỗ -
#                               Wooden House Coffee',
#                               'shop_kind':
#                               'Café/Dessert', 'adress':
#                               '20 BT1B KĐT Văn Quán, 20
#                               BT1B KĐT Văn Quán Quận Hà
#                               Đông Quận Hà Đông Hà Nội',
#                               'opening_time': '07:30 -
#                               23:00', 'opening_state':
#                               'Đang mở cửa',
#                               'price_ship': '20.000đ -
#                               50.000đ', 'rating': '8.5',
#                               'total_review': '17'},
#                               {'shop_id': 114,
#                               'review_id': None,
#                               'shop_name': 'Biabia
#                               Kitchen - Cơm Bento Online
#                               - Giáp Nhất', 'shop_kind':
#                               'Shop Online', 'adress':
#                               '27 Ngõ 213 Giáp Nhất, 27
#                               Ngõ 213 Giáp Nhất Quận
#                               Thanh Xuân Quận Thanh Xuân
#                               Hà Nội', 'opening_time':
#                               '09:30 - 21:30',
#                               'opening_state': 'Đang mở
#                               cửa', 'price_ship':
#                               '25.000đ - 60.000đ',
#                               'rating': '8.4',
#                               'total_review': '9'},
#                               {'shop_id': 245,
#                               'review_id': None,
#                               'shop_name': 'Thuỷ Hoàng -
#                               Chân Gà, Khô Lợn & Trà Sữa
#                               Online', 'shop_kind':
#                               'Shop Online', 'adress':
#                               '7 Ngõ 136 Triều Khúc, 7
#                               Ngõ 136 Triều Khúc Quận
#                               Thanh Xuân Quận Thanh Xuân
#                               Hà Nội', 'opening_time':
#                               '09:00 - 23:00',
#                               'opening_state': 'Đang mở
#                               cửa', 'price_ship':
#                               '12.000đ - 50.000đ',
#                               'rating': '8.4',
#                               'total_review': '1'}])]

# %%
# from ally.tools.load_tools import load_tool_kit


# tool_kit = load_tool_kit("foodally-toolkit")

# %%
# tool_kit[0].run("Ba ba")
